# %%
 ## Basics of Data Analytics.

# %% [markdown]
# # 1.Define the role of a Data Analyst in your own words. What value do they bring to an organization?
# # Ans. A data analyst collects,identifies patterns and trends of data using tools such as SQL,Power BI,Python.....by converting raw data into actionable insights.

# %% [markdown]
# #2. List Three tools commonly used by data analysts and explain what each is mainly used for
#
# #Ans. Three common data analysis tools are Excel,SQL & Tableau.Excel is mainly used for basic data cleaning,manipulation and simple charts creation.SQL manipulates large datasets.Tableau is used for creating interactive dashboards.

# %% [markdown]
# #3. Write the end to end analytics workflow in the correct order and briefly explain each step.
# #Ans.End to end analytics workflow is a systematic interactive process used to transform raw data into actionable insights.
# core steps are
# #1.Data requirement
# #2.Data Collection
# #3.Data cleaning
# #4.Analysis
# #5. Visualisation
# #6. Monitoring

# %% [markdown]
# #4. What is prompt engineering and explain any two types of prompt used in generative AI?
# #Ans. Prompt engineering is process of instructions given to guide gen AI model  to get desired output.
# TWO TYPES OF PROMPT
# 1.Zero Shot Prompting-You give the task to AI and AI by using its general knowledge and  its data insights will do the command
# 2.Few shot prompting- You give the task to AI along with examples and AI on the basis of examples and their patterns will provide the data needed.

# %% [markdown]
# #5. What are the key differences between a data analysts and a business analyst in terms of roles responsibilities and focus?
# #Ans. A Data analyst collects raw data and converts into interactive dashboards by preparing & analysing data,identify trends & patterns.
# A Business Analyst identifies business needs evaluates to create necessary improvements and trends and patterns for business growth.

# %% [markdown]
# #6. Explain any three AI powered ETL (Extract Transform Load ) tools and how they are used in data analytics?
# #Ans.Extract- to pull raw data from the data set or sources
#      Transform - raw data is transformed ,consistent,precise for analysis
#      Load - to transform the data to upload in dataset

# %% [markdown]
# #7.Give three applications of Data Analytics acrossdifferent industries and explain how it creates values.
# #Ans. Retail -Customer Personalisation
#       Healthcare - Predictive dignosis & risk management
#       Finance - fraud detection & risk management

# %% [markdown]
# #8. Explain the evolution of analytics,highlighting the different stages from Descriptive to Generative AI.
# #Ans. Descriptive Analytics means what happened than
#       Diagnostic analytics means cause of the same than
#       Predictive Analytics means prediction of what will happen than
#       Prescriptive Analytics means measures taken for the same and last
#       Generative AI focuses on creating new insights from original content
